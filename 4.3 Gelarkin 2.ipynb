# %%
import torch                               
import DNNI
import matplotlib.pyplot as plt           # plotting
from scipy.integrate import quad
torch.set_default_tensor_type(torch.DoubleTensor)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
import numpy as np
import matplotlib.pyplot as plt
import time
from tqdm import tqdm
print(device)
if device == 'cuda': 
    print(torch.cuda.get_device_name())
# Out:
# cpu

# %%
#LHS
be=1;alpha=1;
def tridiag(n, k1=-1, k2=0, k3=1):
    h=float(1/n) 
    b=2*be*h*np.ones(n)/3
    a=(-3*alpha+be*h)*np.ones(n-1)/6
    c=(3*alpha+be*h)*np.ones(n-1)/6
    td = np.diag(a, k1) + np.diag(b, k2) + np.diag(c, k3)
    td[n-1,n-1] = (3*alpha+2*be*h)/6 
    return td
tridiag(3)
# Out:
# array([[ 0.22222222,  0.55555556,  0.        ],
#        [-0.44444444,  0.22222222,  0.55555556],
#        [ 0.        , -0.44444444,  0.61111111]])

# %%
from pylab import *
from scipy.special.orthogonal import p_roots

def gauss(f,n,a,b):
    [x,w] = p_roots(n+1)
    G=0.5*(b-a)*sum(w*f(0.5*(b-a)*x+0.5*(b+a)))
    return G
def force(n):
    alpha=1;h=float(1/n);be=1
    a=(-3*alpha+be*h)/6
    X = np.linspace(0,1,n+1)
    R = np.ones(int(n))
    #u_0 = 1
    R[0] = n*gauss(lambda x:(X[1]-x)*np.cos(2*x),32,X[0],X[1])#-a*u_0
    for i in range(int(n-1)):
        R[i+1] = n*(gauss(lambda x:(x-X[i])*np.cos(2*x),32,X[i],X[i+1])+gauss(lambda x:(X[i+2]-x)*np.cos(2*x),32,X[i+1],X[i+2]))
    R[n-1] = n*(gauss(lambda x:(x-X[n-1])*np.cos(2*x),32,X[n-1],X[n]))
    return R
force(9)
# Out:
# array([ 0.05532731,  0.10793363,  0.09990448,  0.08696205,  0.06974284,
#         0.04909369,  0.02603012,  0.0016864 , -0.01929155])

# %%
from scipy import linalg
def q(n,func):
    lhs = tridiag(n)
    rhs= func(n)
    return np.linalg.solve(lhs,rhs)

def phi(i,x,n):
    X = np.linspace(0,1,n)
    h = X[1]-X[0]
    if i==0: 
        if x > X[1]:
            v = 0;
        else:
            v = (X[1]-x)/h;
    elif i==n-1:
        if(x<X[n-2]):
            v = 0;
        else:
            v = (x-X[n-2])/h;
    else:
        if(x>X[i+1] or x<X[i-1] ):
            v = 0;
        elif(x<=X[i]):
            v = (x-X[i-1])/h;
        else:
            v = (X[i+1]-x)/h;
    return v

# %% [markdown]
# # Comparison

# %%
def usingFEM(n):
    start = time.time()
    x1 = np.linspace(0,1,10)
    U = np.linspace(0,1,10)
    c = q(n,force)
    for i in range(1,10):
        u=0
        for j in range(n):
            u = u+ c[j]*phi(j,x1[i],n)
        U[i] = u
    actual=1/5*(-np.exp(-x1)+2*np.sin(2*x1)+np.cos(2*x1))
    mse = np.mean(np.abs(actual-U))
    t = time.time()-start
    return t,mse

# %%
def f1(x):
        return torch.cos(2*x)
def f2(x):    
        return x*torch.cos(2*x)

# %%
def get_int(n,iters):
    steps=iters
    x = torch.linspace(0,1,1000).view(-1,1)
    layers = np.array([1,10,10,10,1])
    inn = DNNI.DNNI(layers,device)
    inn.to(device)
    inn.closure(steps=steps,x_train=x,int_f=f1,show=False)
    x_test1 = torch.linspace(0,1,n+1).view(-1,1)
    y1 = inn(x_test1).detach().cpu().numpy()
    #plt.plot(y1-y1[0])
    
    steps=iters
    x = torch.linspace(0,1,1000).view(-1,1)
    layers = np.array([1,10,10,10,1])
    inn2 = DNNI.DNNI(layers,device)
    inn2.to(device)
    inn2.closure(steps=steps,x_train=x,int_f=f2,show=False)
    x_test2 = torch.linspace(0,1,n+1).view(-1,1)
    y2 = inn2(x_test2).detach().cpu().numpy()
    #plt.plot(y2-y2[0])
    return y1,y2

# %%
def force_nn(n,y1,y2):
    alpha=1;h=float(1/n);
    a=(-3*alpha)/6
    X = np.linspace(0,1,n+1)
    R = np.ones(int(n))
    u_0 = 0
    R[0] = n*(-y2[1]+y2[0]+X[1]*(y1[1]-y1[0]))#-a*u_0
    for j in range(n-1):
        R[j+1] = n*(y2[j+1]-y2[j]-X[j]*(y1[j+1]-y1[j]) + X[j+2]*(y1[j+2]-y1[j+1])-(y2[j+2]-y2[j+1]))
    R[n-1] = n*(y2[n]-y2[n-1]-X[n-1]*(y1[n]-y1[n-1]))
    return R
def solver_nn(x,n,func,y1,y2):
    c = q_nn(n,func,y1,y2)
    #plt.plot(c)
    u=0
    for i in range(n):
        u = u+ c[i]*phi(i,x,n)
    return u
def q_nn(n,func,y1,y2):
    lhs = tridiag(n)
    rhs= func(n,y1,y2)
    return np.linalg.solve(lhs,rhs)


def usingDNNI(n,iters):
    start = time.time()
    x1 = np.linspace(0,1,10)
    U = np.linspace(0,1,10)
    y1,y2 = get_int(n,iters)
    c = q_nn(n,force_nn,y1,y2) #only this is different between both
    for i in range(1,10):
        u=0
        for j in range(n):
            u = u+ c[j]*phi(j,x1[i],n)
        U[i] = u
    actual=1/5*(-np.exp(-x1)+2*np.sin(2*x1)+np.cos(2*x1))
    mse = np.mean(np.abs(actual-U))
    t = time.time()-start
    return t,mse

# %%
y1,y2 = get_int(5,5000)
force_nn(5,y1,y2)
# Out:
#  44%|████▎     | 2187/5000 [00:04<00:05, 519.90it/s]
# 100%|██████████| 5000/5000 [00:09<00:00, 545.23it/s]
# array([ 0.09878196,  0.18162465,  0.13721489,  0.07236861, -0.02873386])

# %%
force(5)
# Out:
# array([ 0.09867376,  0.1817691 ,  0.13749334,  0.0715104 , -0.02903543])

# %%
time_gele = []
time_dnni = []
for i in range(5):# for test 1 use range(2)
    time1 = []
    time2 = []
    for i in range(1,11):
        time1.append(usingFEM(i*4400)[0])
        time2.append(usingDNNI(i*4400,1000)[0])# keeping it 1000 for less computation time. Increasing it will increase the no of nodes for break even point
    time_gele.append(time1)
    time_dnni.append(time2)
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 549.45it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 557.17it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 562.68it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 507.87it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 569.24it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 553.39it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 531.66it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 557.46it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 573.38it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 566.23it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 572.28it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 563.76it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 564.42it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 553.71it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 557.06it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 559.76it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 566.70it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 568.55it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 526.34it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 566.27it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 542.92it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 543.71it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 584.13it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 566.43it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 559.63it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 553.81it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 578.30it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 553.16it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 575.19it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 536.60it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 541.79it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 483.21it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 572.64it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 548.04it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 550.98it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 537.67it/s]
#  43%|████▎     | 428/1000 [00:00<00:01, 534.85it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 579.70it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 537.80it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 538.40it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 571.36it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 539.55it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 558.97it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 572.11it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 554.90it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 594.08it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 575.75it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 582.40it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 540.08it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 565.69it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 465.97it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 458.92it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 512.53it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 508.10it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 599.71it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 598.78it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 604.14it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 621.36it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 578.37it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 606.61it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 575.62it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 599.18it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 609.07it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 609.75it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 597.34it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 597.53it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 592.79it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 595.43it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 594.96it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 600.01it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 597.68it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 618.39it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 594.18it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 601.05it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 600.72it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 609.35it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 580.32it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 607.90it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 487.14it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 553.79it/s]
# 100%|██████████| 1000/1000 [00:02<00:00, 458.83it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 512.00it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 548.58it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 533.85it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 555.60it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 531.82it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 550.50it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 542.85it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 537.74it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 538.51it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 545.84it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 507.77it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 545.17it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 527.84it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 584.42it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 589.01it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 534.02it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 548.08it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 531.25it/s]
# 100%|██████████| 1000/1000 [00:01<00:00, 536.11it/s]

# %%
# test 1 (average of 2 iterations)
t1 = np.array(time_gele)
t2 = np.array(time_dnni)
mean_t1 = (t1[0]+t1[1])/2
mean_t2 = (t2[0]+t2[1])/2

fig = plt.figure(dpi=600)
fig.patch.set_facecolor('xkcd:white')
nodes = np.linspace(4400,44000,10)
plt.plot(nodes,np.array(mean_t1),'purple',label='Quadrature based Galerkin Method',linewidth=0.7)
plt.plot(nodes,np.array(mean_t2),'y',label='DNNI based Galerkin Method',linewidth=0.7)
plt.xlabel('No. of Nodes')
plt.ylabel('Time Taken(s)')
plt.legend()
plt.savefig('DE2.png',bbox_inches='tight')

# %% [markdown]
# # Test 2

# %%
#average of 5 iterations
t1 = np.array(time_gele)
t2 = np.array(time_dnni)
mean_t1 = (t1[0]+t1[1]+t1[2]+t1[3]+t1[4])/5
mean_t2 = (t2[0]+t2[1]+t2[2]+t2[3]+t2[4])/5

fig = plt.figure(dpi=600)
fig.patch.set_facecolor('xkcd:white')
nodes = np.linspace(4400,44000,10)
plt.plot(nodes,np.array(mean_t1),'purple',label='Naive Gelarkin Method',linewidth=0.7)
plt.plot(nodes,np.array(mean_t2),'y',label='DNNI based Gelarkin Method',linewidth=0.7)
plt.xlabel('No. of Nodes ')
plt.ylabel('Time Taken(s) ')
plt.legend()
#plt.savefig('DE2.png',bbox_inches='tight')
